# %%
import pandas as pd
import numpy as np
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash_html_components import Br
from dash.dependencies import Input, Output
import plotly.express as px
import dash_table
from readDB import ReadMongoData as db

# %%
bookings = db.getBookings()
agents = db.getAgents()
agentscom = db.getAgentCommissions()
agencies = db.getAgencies()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-a52af0033886> in <module>
#       2 agents = db.getAgents()
#       3 agentscom = db.getAgentCommissions()
# ----> 4 agencies = db.getAgencies()
#
# AttributeError: module 'readDB.ReadMongoData' has no attribute 'getAgencies'

# %%
agentscom
# Out:
#                           AgentCommission  AgentId __v
# _id
# 610c9d613db7864cd4bd57cf               31        1   0
# 610c9e5d1b03d84644a7a435               48        7   0
# 610ebf7d92465e2580eb5828               28        6   0
# 610ee4e9eee5a24ec64610cf               48        2   0
# 610ee58eeee5a24ec64610ef               48        1   0
# ...                                   ...      ...  ..
# 61130bb34e20b15d8c0f39f4               48        3   0
# 61130bc84e20b15d8c0f39fa               48        3   0
# 61130bff4e20b15d8c0f3a00               48        3   0
# 61130c4a4e20b15d8c0f3a06               48        3   0
# 61131d1d0eb7115decf3d532               48        4   0
#
# [135 rows x 3 columns]

# %%
agentscom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135 entries, 610c9d613db7864cd4bd57cf to 61131d1d0eb7115decf3d532
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AgentCommission  135 non-null    int64
#  1   AgentId          135 non-null    int64
#  2   __v              135 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 4.2+ KB

# %%
agentscom_agents = pd.merge(agents,agentscom, on = 'AgentId')
bookings_agents = pd.merge(bookings, agentscom_agents, on="AgentId")
bookings_agents
# Out:
#       AgentId             BookingDate  PackageId  customerId  totalPrice  \
# 0           1 2021-08-06 02:24:10.912          2           1        3310
# 1           1 2021-08-06 02:24:10.912          2           1        3310
# 2           1 2021-08-06 02:24:10.912          2           1        3310
# 3           1 2021-08-06 02:24:10.912          2           1        3310
# 4           1 2021-08-06 02:24:10.912          2           1        3310
# ...       ...                     ...        ...         ...         ...
# 1886        8 2021-08-09 00:49:33.775          8        1234       39204
# 1887        8 2021-08-09 00:49:33.775          8        1234       39204
# 1888        8 2021-08-09 00:49:33.775          8        1234       39204
# 1889        8 2021-08-09 00:49:33.775          8        1234       39204
# 1890        8 2021-08-09 00:49:33.775          8        1234       39204
#
#       travellerCount                title PkgStartDate  __v_x  _id  ...  \
# 0                  1  Polynesian Paradise   2005-12-12      0    1  ...
# 1                  1  Polynesian Paradise   2005-12-12      0    1  ...
# 2                  1  Polynesian Paradise   2005-12-12      0    1  ...
# 3                  1  Polynesian Paradise   2005-12-12      0    1  ...
# 4                  1  Polynesian Paradise   2005-12-12      0    1  ...
# ...              ...                  ...          ...    ...  ...  ...
# 1886              12          Maui Hawaii   2021-10-25      0    8  ...
# 1887              12          Maui Hawaii   2021-10-25      0    8  ...
# 1888              12          Maui Hawaii   2021-10-25      0    8  ...
# 1889              12          Maui Hawaii   2021-10-25      0    8  ...
# 1890              12          Maui Hawaii   2021-10-25      0    8  ...
#
#      AgtMiddleInitial AgtLastName     AgtBusPhone  \
# 0                None      Delton  (403) 210-7801
# 1                None      Delton  (403) 210-7801
# 2                None      Delton  (403) 210-7801
# 3                None      Delton  (403) 210-7801
# 4                None      Delton  (403) 210-7801
# ...               ...         ...             ...
# 1886             None     Merrill  (403) 210-7868
# 1887             None     Merrill  (403) 210-7868
# 1888             None     Merrill  (403) 210-7868
# 1889             None     Merrill  (403) 210-7868
# 1890             None     Merrill  (403) 210-7868
#
#                             AgtEmail   AgtPosition AgencyId password  \
# 0     janet.delton@travelexperts.com  Senior Agent        1      NaN
# 1     janet.delton@travelexperts.com  Senior Agent        1      NaN
# 2     janet.delton@travelexperts.com  Senior Agent        1      NaN
# 3     janet.delton@travelexperts.com  Senior Agent        1      NaN
# 4     janet.delton@travelexperts.com  Senior Agent        1      NaN
# ...                              ...           ...      ...      ...
# 1886  jane.merrill@travelexperts.com  Senior Agent        2      NaN
# 1887  jane.merrill@travelexperts.com  Senior Agent        2      NaN
# 1888  jane.merrill@travelexperts.com  Senior Agent        2      NaN
# 1889  jane.merrill@travelexperts.com  Senior Agent        2      NaN
# 1890  jane.merrill@travelexperts.com  Senior Agent        2      NaN
#
#       username AgentCommission __v_y
# 0          NaN              31     0
# 1          NaN              48     0
# 2          NaN              48     0
# 3          NaN              48     0
# 4          NaN              48     0
# ...        ...             ...   ...
# 1886       NaN              45     0
# 1887       NaN              30     0
# 1888       NaN              32     0
# 1889       NaN              40     0
# 1890       NaN              30     0
#
# [1891 rows x 22 columns]

# %%
bookings_agents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1891 entries, 0 to 1890
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AgentId           1891 non-null   int64
#  1   BookingDate       1891 non-null   datetime64[ns]
#  2   PackageId         1891 non-null   int64
#  3   customerId        1891 non-null   int64
#  4   totalPrice        1891 non-null   int64
#  5   travellerCount    1891 non-null   int64
#  6   title             1891 non-null   object
#  7   PkgStartDate      1891 non-null   datetime64[ns]
#  8   __v_x             1891 non-null   int64
#  9   _id               1891 non-null   int64
#  10  role              1891 non-null   object
#  11  AgtFirstName      1891 non-null   object
#  12  AgtMiddleInitial  1436 non-null   object
#  13  AgtLastName       1891 non-null   object
#  14  AgtBusPhone       1891 non-null   object
#  15  AgtEmail          1891 non-null   object
#  16  AgtPosition       1891 non-null   object
#  17  AgencyId          1891 non-null   int64
#  18  password          190 non-null    object
#  19  username          190 non-null    object
#  20  AgentCommission   1891 non-null   int64
#  21  __v_y             1891 non-null   object
# dtypes: datetime64[ns](2), int64(9), object(11)
# memory usage: 339.8+ KB

# %%
packages = db.getPackages()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-c56d65076c89> in <module>
# ----> 1 packages = db.getPackages()
#
# AttributeError: module 'readDB.ReadMongoData' has no attribute 'getPackages'
